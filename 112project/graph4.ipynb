# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('datacleaned.xlsx')

# %%
data.head(10)
# Out:
#    Gender   Race Marital Status  Perform Evaluation  Monthly Income  \
# 0  Female  White            Yes                   3    14971.987864
# 1  Female  White            Yes                   2    16336.367043
# 2  Female  White            Yes                   7    18834.848936
# 3  Female  White            Yes                   5    16728.815432
# 4  Female  White            Yes                   2    11303.189517
# 5    Male  White            Yes                   4    16886.917981
# 6  Female  White            Yes                   2    11394.749699
# 7    Male  White            Yes                   5    18363.976057
# 8    Male  White            Yes                   3    13505.241386
# 9    Male  White            Yes                   2    13374.086671
#
#    Working Years                          Position Education Level  \
# 0              3  Production Technician Department      University
# 1              4  Production Technician Department      University
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Gender              300 non-null    object
#  1   Race                300 non-null    object
#  2   Marital Status      300 non-null    object
#  3   Perform Evaluation  300 non-null    int64
#  4   Monthly Income      300 non-null    float64
#  5   Working Years       300 non-null    int64
#  6   Position            300 non-null    object
#  7   Education Level     300 non-null    object
#  8   Location            300 non-null    object
#  9   Remote              300 non-null    object
#  10  Age                 300 non-null    int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 25.9+ KB

# %%
#What is the relationship between education level and montly income?
#There is a positive linear relationship between education level and monthly income. 
sns.barplot(data = data, x = 'Monthly Income', y= 'Education Level', color  = 'darkred',ci=None )
plt.title('Relationship between education level and montly income', fontweight="bold",fontsize=14)
plt.show()
